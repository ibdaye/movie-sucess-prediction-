# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credits_df = pd.read_csv('credits.csv')
movies_df = pd.read_csv('movies.csv')
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movies_df.drop(['id' , 'vote_count' , 'production_companies' , 'keywords' , 'homepage'], axis=1)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#      original_language                            original_title  \
# 0                   en                                    Avatar
# 1                   en  Pirates of the Caribbean: At World's End
# 2                   en                                   Spectre
# 3                   en                     The Dark Knight Rises
# 4                   en                               John Carter
# ...                ...                                       ...
# 4798                es                               El Mariachi
# 4799                en                                 Newlyweds
# 4800                en                 Signed, Sealed, Delivered
# 4801                en                          Shanghai Calling
# 4802                en                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average
# 0                                       Avatar           7.2
# 1     Pirates of the Caribbean: At World's End           6.9
# 2                                      Spectre           6.3
# 3                        The Dark Knight Rises           7.6
# 4                                  John Carter           6.1
# ...                                        ...           ...
# 4798                               El Mariachi           6.6
# 4799                                 Newlyweds           5.9
# 4800                 Signed, Sealed, Delivered           7.0
# 4801                          Shanghai Calling           5.7
# 4802                         My Date with Drew           6.3
#
# [4803 rows x 15 columns]

# %%
from datetime import datetime
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
movies_df = pd.merge(movies_df, credits_df, left_on ='id', right_on='movie_id', how='left', suffixes=('', '_y'))

movies_df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 24 columns]

# %%
movies_df.drop(['tagline' , 'original_language' , 'original_language' , 'original_title' , 'overview' , 'title_y'], axis=1)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords  popularity  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  150.437577
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...  139.082615
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...  107.376788
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...  112.312950
# 4     [{"id": 818, "name": "based on novel"}, {"id":...   43.926995
# ...                                                 ...         ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...   14.269792
# 4799                                                 []    0.642552
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...    1.444476
# 4801                                                 []    0.857008
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                     title  vote_average  \
# 0     Released                                    Avatar           7.2
# 1     Released  Pirates of the Caribbean: At World's End           6.9
# 2     Released                                   Spectre           6.3
# 3     Released                     The Dark Knight Rises           7.6
# 4     Released                               John Carter           6.1
# ...        ...                                       ...           ...
# 4798  Released                               El Mariachi           6.6
# 4799  Released                                 Newlyweds           5.9
# 4800  Released                 Signed, Sealed, Delivered           7.0
# 4801  Released                          Shanghai Calling           5.7
# 4802  Released                         My Date with Drew           6.3
#
#       vote_count  movie_id                                               cast  \
# 0          11800     19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1           4500       285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2           4466    206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3           9106     49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4           2124     49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...          ...       ...                                                ...
# 4798         238      9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799           5     72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800           6    231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801           7    126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802          16     25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4803 rows x 19 columns]

# %%
import ast, json

# %%
def parse_col_json(column, key):
    """
    Args:
        column: string
            name of the column to be processed.
        key: string
            name of the dictionary key which needs to be extracted
    """
    for index,i in zip(movies_df.index,movies_df[column].apply(json.loads)):
        list1=[]
        for j in range(len(i)):
            list1.append((i[j][key]))
        movies_df.loc[index,column]=str(list1)
    
parse_col_json('genres', 'name')
parse_col_json('spoken_languages', 'name')
parse_col_json('cast', 'name')
parse_col_json('production_countries', 'name')

movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000                   ['Action', 'Adventure', 'Crime']
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']
# 4  260000000         ['Action', 'Adventure', 'Science Fiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0                             ['English', 'Español']  Released
# 1                                        ['English']  Released
# 2  ['Français', 'English', 'Español', 'Italiano',...  Released
# 3                                        ['English']  Released
# 4                                        ['English']  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 24 columns]

# %%
print(movies_df.shape)
movies_df = movies_df.drop_duplicates(keep='first')
print(movies_df.shape)
# Out:
# (4803, 24)
# (4803, 24)

# %%
cols = ['budget', 'revenue']
movies_df[cols] = movies_df[cols].replace(0, np.nan)

# %%
movies_df.dropna(subset=cols, inplace=True)
movies_df.shape
# Out:
# (3229, 24)

# %%
movies_df.release_date = pd.to_datetime(movies_df['release_date'])
movies_df.head()
# Out:
#         budget                                             genres  \
# 0  237000000.0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000.0                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000.0                   ['Action', 'Adventure', 'Crime']
# 3  250000000.0           ['Action', 'Crime', 'Drama', 'Thriller']
# 4  260000000.0         ['Action', 'Adventure', 'Science Fiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#                                     spoken_languages    status  \
# 0                             ['English', 'Español']  Released
# 1                                        ['English']  Released
# 2  ['Français', 'English', 'Español', 'Italiano',...  Released
# 3                                        ['English']  Released
# 4                                        ['English']  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 24 columns]

# %%
movies_df['release_year'] = movies_df['release_date'].dt.year
movies_df.head()
# Out:
#         budget                                             genres  \
# 0  237000000.0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1  300000000.0                 ['Adventure', 'Fantasy', 'Action']
# 2  245000000.0                   ['Action', 'Adventure', 'Crime']
# 3  250000000.0           ['Action', 'Crime', 'Drama', 'Thriller']
# 4  260000000.0         ['Action', 'Adventure', 'Science Fiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...    status  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  Released
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...  Released
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...  Released
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  Released
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average vote_count movie_id  \
# 0                                    Avatar           7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End           6.9       4500      285
# 2                                   Spectre           6.3       4466   206647
# 3                     The Dark Knight Rises           7.6       9106    49026
# 4                               John Carter           6.1       2124    49529
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                 crew  release_year
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...          2009
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...          2007
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...          2015
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...          2012
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...          2012
#
# [5 rows x 25 columns]

# %%
change_cols=['budget', 'revenue']

movies_df[change_cols]=movies_df[change_cols].applymap(np.int64)
movies_df.dtypes
# Out:
# budget                           int64
# genres                          object
# homepage                        object
# id                               int64
# keywords                        object
# original_language               object
# original_title                  object
# overview                        object
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                          int64
# runtime                        float64
# spoken_languages                object
# status                          object
# tagline                         object
# title                           object
# vote_average                   float64
# vote_count                       int64
# movie_id                         int64
# title_y                         object
# cast                            object
# crew                            object
# release_year                     int64
# dtype: object

# %%
expensive_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
expensive_movies_df
# Out:
#        budget                                             genres  \
# 17  380000000                 ['Adventure', 'Action', 'Fantasy']
# 1   300000000                 ['Adventure', 'Fantasy', 'Action']
# 7   280000000         ['Action', 'Adventure', 'Science Fiction']
# 10  270000000  ['Adventure', 'Fantasy', 'Action', 'Science Fi...
# 4   260000000         ['Action', 'Adventure', 'Science Fiction']
#
#                                              homepage     id  \
# 17  http://disney.go.com/pirates/index-on-stranger...   1865
# 1        http://disney.go.com/disneypictures/pirates/    285
# 7   http://marvel.com/movies/movie/193/avengers_ag...  99861
# 10                            http://www.superman.com   1452
# 4                http://movies.disney.com/john-carter  49529
#
#                                              keywords original_language  \
# 17  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
# 1   [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 7   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 10  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 4   [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                                  original_title  \
# 17  Pirates of the Caribbean: On Stranger Tides
# 1      Pirates of the Caribbean: At World's End
# 7                       Avengers: Age of Ultron
# 10                             Superman Returns
# 4                                   John Carter
#
#                                              overview  popularity  \
# 17  Captain Jack Sparrow crosses paths with a woma...  135.413856
# 1   Captain Barbossa, long believed to be dead, ha...  139.082615
# 7   When Tony Stark tries to jumpstart a dormant p...  134.279229
# 10  Superman returns to discover his 5-year absenc...   57.925623
# 4   John Carter is a war-weary, former military ca...   43.926995
#
#                                  production_companies  ...    status  \
# 17  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...  Released
# 1   [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...  Released
# 7   [{"name": "Marvel Studios", "id": 420}, {"name...  ...  Released
# 10  [{"name": "DC Comics", "id": 429}, {"name": "L...  ...  Released
# 4         [{"name": "Walt Disney Pictures", "id": 2}]  ...  Released
#
#                                            tagline  \
# 17                     Live Forever Or Die Trying.
# 1   At the end of the world, the adventure begins.
# 7                              A New Age Has Come.
# 10                                             NaN
# 4             Lost in our world, found in another.
#
#                                           title  vote_average vote_count  \
# 17  Pirates of the Caribbean: On Stranger Tides           6.4       4948
# 1      Pirates of the Caribbean: At World's End           6.9       4500
# 7                       Avengers: Age of Ultron           7.3       6767
# 10                             Superman Returns           5.4       1400
# 4                                   John Carter           6.1       2124
#
#    movie_id                                      title_y  \
# 17     1865  Pirates of the Caribbean: On Stranger Tides
# 1       285     Pirates of the Caribbean: At World's End
# 7     99861                      Avengers: Age of Ultron
# 10     1452                             Superman Returns
# 4     49529                                  John Carter
#
#                                                  cast  \
# 17  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...
# 1   ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 7   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...
# 10  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...
# 4   ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                  crew  release_year
# 17  [{"credit_id": "566b4f54c3a3683f56005151", "de...          2011
# 1   [{"credit_id": "52fe4232c3a36847f800b579", "de...          2007
# 7   [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...          2015
# 10  [{"credit_id": "553bef6a9251416874003c8f", "de...          2006
# 4   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...          2012
#
# [5 rows x 25 columns]

# %%
def find_min_max_in(col):
    """
    The function takes in a column and returns the top 5
    and bottom 5 movies dataframe in that column.
    
    args:
        col: string - column name
    return:
        info_df: dataframe - final 5 movies dataframe
    """
    
    top = movies_df[col].idxmax()
    top_df = pd.DataFrame(movies_df.loc[top])
    
    bottom = movies_df[col].idxmin()
    bottom_df = pd.DataFrame(movies_df.loc[bottom])
    
    info_df = pd.concat([top_df, bottom_df], axis=1)
    return info_df

find_min_max_in('budget')
# Out:
#                                                                    17    \
# budget                                                        380000000
# genres                               ['Adventure', 'Action', 'Fantasy']
# homepage              http://disney.go.com/pirates/index-on-stranger...
# id                                                                 1865
# keywords              [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
# original_language                                                    en
# original_title              Pirates of the Caribbean: On Stranger Tides
# overview              Captain Jack Sparrow crosses paths with a woma...
# popularity                                                      135.414
# production_companies  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# production_countries                       ['United States of America']
# release_date                                        2011-05-14 00:00:00
# revenue                                                      1045713802
# runtime                                                             136
# spoken_languages                                 ['English', 'Español']
# status                                                         Released
# tagline                                     Live Forever Or Die Trying.
# title                       Pirates of the Caribbean: On Stranger Tides
# vote_average                                                        6.4
# vote_count                                                         4948
# movie_id                                                           1865
# title_y                     Pirates of the Caribbean: On Stranger Tides
# cast                  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...
# crew                  [{"credit_id": "566b4f54c3a3683f56005151", "de...
# release_year                                                       2011
#
#                                                                    4238
# budget                                                                1
# genres                                              ['Drama', 'Comedy']
# homepage                                                            NaN
# id                                                                 3082
# keywords              [{"id": 1382, "name": "factory"}, {"id": 1546,...
# original_language                                                    en
# original_title                                             Modern Times
# overview              The Tramp struggles to live in modern industri...
# popularity                                                      28.2765
# production_companies  [{"name": "United Artists", "id": 60}, {"name"...
# production_countries                       ['United States of America']
# release_date                                        1936-02-05 00:00:00
# revenue                                                         8500000
# runtime                                                              87
# spoken_languages                                            ['English']
# status                                                         Released
# tagline               He stands alone as the greatest entertainer of...
# title                                                      Modern Times
# vote_average                                                        8.1
# vote_count                                                          856
# movie_id                                                           3082
# title_y                                                    Modern Times
# cast                  ['Charlie Chaplin', 'Paulette Goddard', 'Henry...
# crew                  [{"credit_id": "5621aeadc3a3680e1d00a09a", "de...
# release_year                                                       1936

# %%
movies_df['profit'] = movies_df['revenue'] - movies_df['budget']
cols = ['budget',
         'profit',
         'revenue',
         'genres',
         'id',
         'popularity',
         'production_countries',
        'release_date',
        'release_year',
         'runtime',
         'spoken_languages',
         'title',
        'cast',
         'vote_average',
         'vote_count']
movies_df = movies_df[cols]
movies_df.sort_values(by = ['budget'], ascending=False).head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  \
# 17  Pirates of the Caribbean: On Stranger Tides
# 1      Pirates of the Caribbean: At World's End
# 7                       Avengers: Age of Ultron
# 10                             Superman Returns
# 4                                   John Carter
#
#                                                  cast  vote_average  \
# 17  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...           6.4
# 1   ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9
# 7   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 10  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...           5.4
# 4   ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...           6.1
#
#     vote_count
# 17        4948
# 1         4500
# 7         6767
# 10        1400
# 4         2124

# %%
find_min_max_in('profit')
# Out:
#                                                                      0   \
# budget                                                        237000000
# profit                                                       2550965087
# revenue                                                      2787965087
# genres                ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# id                                                                19995
# popularity                                                      150.438
# production_countries     ['United States of America', 'United Kingdom']
# release_date                                        2009-12-10 00:00:00
# release_year                                                       2009
# runtime                                                             162
# spoken_languages                                 ['English', 'Español']
# title                                                            Avatar
# cast                  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# vote_average                                                        7.2
# vote_count                                                        11800
#
#                                                                      13
# budget                                                        255000000
# profit                                                       -165710090
# revenue                                                        89289910
# genres                               ['Action', 'Adventure', 'Western']
# id                                                                57201
# popularity                                                       49.047
# production_countries                       ['United States of America']
# release_date                                        2013-07-03 00:00:00
# release_year                                                       2013
# runtime                                                             149
# spoken_languages                                            ['English']
# title                                                   The Lone Ranger
# cast                  ['Johnny Depp', 'Armie Hammer', 'William Ficht...
# vote_average                                                        5.9
# vote_count                                                         2311

# %%
popular_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
popular_movies_df.head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  \
# 17  Pirates of the Caribbean: On Stranger Tides
# 1      Pirates of the Caribbean: At World's End
# 7                       Avengers: Age of Ultron
# 10                             Superman Returns
# 4                                   John Carter
#
#                                                  cast  vote_average  \
# 17  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...           6.4
# 1   ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9
# 7   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 10  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...           5.4
# 4   ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...           6.1
#
#     vote_count
# 17        4948
# 1         4500
# 7         6767
# 10        1400
# 4         2124

# %%
find_min_max_in('popularity')
# Out:
#                                                                    546   \
# budget                                                         74000000
# profit                                                       1082730962
# revenue                                                      1156730962
# genres                   ['Family', 'Animation', 'Adventure', 'Comedy']
# id                                                               211672
# popularity                                                      875.581
# production_countries                       ['United States of America']
# release_date                                        2015-06-17 00:00:00
# release_year                                                       2015
# runtime                                                              91
# spoken_languages                                            ['English']
# title                                                           Minions
# cast                  ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton...
# vote_average                                                        6.4
# vote_count                                                         4571
#
#                                                                    3921
# budget                                                          3000000
# profit                                                          3804016
# revenue                                                         6804016
# genres                                                        ['Drama']
# id                                                                44634
# popularity                                                     0.019984
# production_countries                       ['United States of America']
# release_date                                        2004-09-30 00:00:00
# release_year                                                       2004
# runtime                                                              94
# spoken_languages                                            ['English']
# title                                             Woman Thou Art Loosed
# cast                  ['Kimberly Elise', 'Loretta Devine', 'Debbi Mo...
# vote_average                                                          5
# vote_count                                                            3

# %%
find_min_max_in('runtime')
# Out:
#                                                                    2384  \
# budget                                                         18000000
# profit                                                        -17128721
# revenue                                                          871279
# genres                        ['Crime', 'Drama', 'Thriller', 'History']
# id                                                                43434
# popularity                                                      1.13838
# production_countries                              ['France', 'Germany']
# release_date                                        2010-05-19 00:00:00
# release_year                                                       2010
# runtime                                                             338
# spoken_languages      ['Français', 'Deutsch', 'English', 'Español', ...
# title                                                            Carlos
# cast                  ['Edgar Ramírez', 'Alexander Scheer', 'Fadi Ab...
# vote_average                                                        6.7
# vote_count                                                           50
#
#                                                                    3626
# budget                                                          5000000
# profit                                                          -925977
# revenue                                                         4074023
# genres                                                  ['Documentary']
# id                                                                78394
# popularity                                                      4.49837
# production_countries                       ['France', 'United Kingdom']
# release_date                                        2010-05-14 00:00:00
# release_year                                                       2010
# runtime                                                              41
# spoken_languages                                            ['English']
# title                        Sea Rex 3D: Journey to a Prehistoric World
# cast                  ['Guillaume Denaiffe', 'Norbert Ferrer', 'Chlo...
# vote_average                                                        5.9
# vote_count                                                           11

# %%
movies_df['runtime'].mean()
# Out:
# 110.72437287085785

# %%
movies_df[movies_df['vote_average'] >= 7.0]
# Out:
#          budget      profit     revenue  \
# 0     237000000  2550965087  2787965087
# 3     250000000   834939099  1084939099
# 6     260000000   331794936   591794936
# 7     280000000  1125403694  1405403694
# 8     250000000   683959197   933959197
# ...         ...         ...         ...
# 4713     160000     6546368     6706368
# 4724      10000     6990000     7000000
# 4738      60000     3161152     3221152
# 4773      27000     3124130     3151130
# 4792      20000       79000       99000
#
#                                                  genres     id  popularity  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...  19995  150.437577
# 3              ['Action', 'Crime', 'Drama', 'Thriller']  49026  112.312950
# 6                               ['Animation', 'Family']  38757   48.681969
# 7            ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 8                    ['Adventure', 'Fantasy', 'Family']    767   98.885637
# ...                                                 ...    ...         ...
# 4713                         ['Documentary', 'History']   1779    3.284903
# 4724  ['Drama', 'Fantasy', 'Horror', 'Science Fiction']    985   20.399578
# 4738                   ['Mystery', 'Drama', 'Thriller']    473   27.788067
# 4773                                         ['Comedy']   2292   19.748658
# 4792         ['Crime', 'Horror', 'Mystery', 'Thriller']  36095    0.212443
#
#                                 production_countries release_date  \
# 0     ['United States of America', 'United Kingdom']   2009-12-10
# 3                       ['United States of America']   2012-07-16
# 6                       ['United States of America']   2010-11-24
# 7                       ['United States of America']   2015-04-22
# 8     ['United Kingdom', 'United States of America']   2009-07-07
# ...                                              ...          ...
# 4713                    ['United States of America']   1989-09-01
# 4724                    ['United States of America']   1977-03-19
# 4738                    ['United States of America']   1998-07-10
# 4773                    ['United States of America']   1994-09-13
# 4792                                       ['Japan']   1997-11-06
#
#       release_year  runtime        spoken_languages  \
# 0             2009    162.0  ['English', 'Español']
# 3             2012    165.0             ['English']
# 6             2010    100.0             ['English']
# 7             2015    141.0             ['English']
# 8             2009    153.0             ['English']
# ...            ...      ...                     ...
# 4713          1989     91.0             ['English']
# 4724          1977     89.0             ['English']
# 4738          1998     84.0             ['English']
# 4773          1994     92.0             ['English']
# 4792          1997    111.0                 ['日本語']
#
#                                        title  \
# 0                                     Avatar
# 3                      The Dark Knight Rises
# 6                                    Tangled
# 7                    Avengers: Age of Ultron
# 8     Harry Potter and the Half-Blood Prince
# ...                                      ...
# 4713                              Roger & Me
# 4724                              Eraserhead
# 4738                                      Pi
# 4773                                  Clerks
# 4792                                    Cure
#
#                                                    cast  vote_average  \
# 0     ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2
# 3     ['Christian Bale', 'Michael Caine', 'Gary Oldm...           7.6
# 6     ['Zachary Levi', 'Mandy Moore', 'Donna Murphy'...           7.4
# 7     ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 8     ['Daniel Radcliffe', 'Rupert Grint', 'Emma Wat...           7.4
# ...                                                 ...           ...
# 4713  ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...           7.4
# 4724  ['Jack Nance', 'Charlotte Stewart', 'Allen Jos...           7.5
# 4738  ['Sean Gullette', 'Mark Margolis', 'Ben Shenkm...           7.1
# 4773  ["Brian O'Halloran", 'Jeff Anderson', 'Jason M...           7.4
# 4792  ['Koji Yakusho', 'Masato Hagiwara', 'Tsuyoshi ...           7.4
#
#       vote_count
# 0          11800
# 3           9106
# 6           3330
# 7           6767
# 8           5293
# ...          ...
# 4713          90
# 4724         485
# 4738         586
# 4773         755
# 4792          63
#
# [768 rows x 15 columns]

# %%
plt.figure(figsize=(9,5), dpi = 100)

#On x-axis 
plt.xlabel('Runtime of the Movies', fontsize = 15)
#On y-axis 
plt.ylabel('Nos.of Movies in the Dataset', fontsize=15)
#Name of the graph
plt.title('Runtime of all the movies', fontsize=15)

#giving a histogram plot
plt.hist(movies_df['runtime'], rwidth = 0.9, bins =35)
#displays the plot
plt.show()

# %%
profits_year = movies_df.groupby('release_year')['profit'].sum()

#figure size(width, height)
plt.figure(figsize=(12,6), dpi = 130)

#on x-axis
plt.xlabel('Release Year of Movies in the data set', fontsize = 12)
#on y-axis
plt.ylabel('Profits earned by Movies', fontsize = 12)
#title of the line plot
plt.title('Representing Total Profits earned by all movies Vs Year of their release.')

#plotting the graph
plt.plot(profits_year)

#displaying the line plot
plt.show()

# %%
profits_year.idxmax()
# Out:
# 2014

# %%
#selecting the movies having profit $50M or more
profit_data = movies_df[movies_df['profit'] >= 50000000]

#reindexing new data
profit_data.index = range(len(profit_data))

#we will start from 1 instead of 0
profit_data.index = profit_data.index + 1

#printing the changed dataset
profit_data.head(3)
# Out:
#       budget      profit     revenue  \
# 1  237000000  2550965087  2787965087
# 2  300000000   661000000   961000000
# 3  245000000   635674609   880674609
#
#                                               genres      id  popularity  \
# 1  ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 2                 ['Adventure', 'Fantasy', 'Action']     285  139.082615
# 3                   ['Action', 'Adventure', 'Crime']  206647  107.376788
#
#                              production_countries release_date  release_year  \
# 1  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 2                    ['United States of America']   2007-05-19          2007
# 3  ['United Kingdom', 'United States of America']   2015-10-26          2015
#
#    runtime                                   spoken_languages  \
# 1    162.0                             ['English', 'Español']
# 2    169.0                                        ['English']
# 3    148.0  ['Français', 'English', 'Español', 'Italiano',...
#
#                                       title  \
# 1                                    Avatar
# 2  Pirates of the Caribbean: At World's End
# 3                                   Spectre
#
#                                                 cast  vote_average  vote_count
# 1  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2       11800
# 2  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9        4500
# 3  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...           6.3        4466

# %%
profit_data['genres']=profit_data['genres'].str.strip('[]').str.replace(' ','').str.replace("'",'')

profit_data['genres']=profit_data['genres'].str.split(',')

profit_data.head()
# Out:
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       budget      profit     revenue  \
# 1  237000000  2550965087  2787965087
# 2  300000000   661000000   961000000
# 3  245000000   635674609   880674609
# 4  250000000   834939099  1084939099
# 5  258000000   632871626   890871626
#
#                                          genres      id  popularity  \
# 1  [Action, Adventure, Fantasy, ScienceFiction]   19995  150.437577
# 2                  [Adventure, Fantasy, Action]     285  139.082615
# 3                    [Action, Adventure, Crime]  206647  107.376788
# 4              [Action, Crime, Drama, Thriller]   49026  112.312950
# 5                  [Fantasy, Action, Adventure]     559  115.699814
#
#                              production_countries release_date  release_year  \
# 1  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 2                    ['United States of America']   2007-05-19          2007
# 3  ['United Kingdom', 'United States of America']   2015-10-26          2015
# 4                    ['United States of America']   2012-07-16          2012
# 5                    ['United States of America']   2007-05-01          2007
#
#    runtime                                   spoken_languages  \
# 1    162.0                             ['English', 'Español']
# 2    169.0                                        ['English']
# 3    148.0  ['Français', 'English', 'Español', 'Italiano',...
# 4    165.0                                        ['English']
# 5    139.0                            ['English', 'Français']
#
#                                       title  \
# 1                                    Avatar
# 2  Pirates of the Caribbean: At World's End
# 3                                   Spectre
# 4                     The Dark Knight Rises
# 5                              Spider-Man 3
#
#                                                 cast  vote_average  vote_count
# 1  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2       11800
# 2  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9        4500
# 3  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...           6.3        4466
# 4  ['Christian Bale', 'Michael Caine', 'Gary Oldm...           7.6        9106
# 5  ['Tobey Maguire', 'Kirsten Dunst', 'James Fran...           5.9        3576

# %%
plt.subplots(figsize=(12,10))
list1=[]

# extending the list to 
for i in profit_data['genres']:
    list1.extend(i)
    
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(
    width=0.9,
    color=sns.color_palette('summer_r',10))

for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Genres')
plt.show()

# %%
profit_data['cast']=profit_data['cast'].str.strip('[]').str.replace(' ','').str.replace("'",'')
profit_data['cast']=profit_data['cast'].str.split(',')

plt.subplots(figsize=(12,10))
list1=[]
for i in profit_data['cast']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('summer_r',10))
for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Cast')
plt.show()
# Out:
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
profit_data['profit'].mean()
profit_data['revenue'].mean()
# Out:
# 262022090.17768925

# %%
profit_data['runtime'].mean()
# Out:
# 114.37928286852589

# %%
profit_data['budget'].mean()
# Out:
# 63032056.92111554

# %%
profit_data['spoken_languages']=profit_data['spoken_languages'].str.strip('[]').str.replace(' ','').str.replace("'",'')
profit_data['spoken_languages']=profit_data['spoken_languages'].str.split(',')

plt.subplots(figsize=(12,10))
list1=[]
for i in profit_data['spoken_languages']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('summer_r',10))
for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Cast')
plt.show()
# Out:
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26222 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35805 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26222 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\ibibo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35805 missing from current font.
#   font.set_text(s, 0, flags=flags)
